# %%
import pandas as pd

# %%
df = pd.read_csv("simulated.csv")

# %%
df
# Out:
#     Unnamed: 0          Function Name  Best Value  \
# 0            0                 Ackley    4.682732
# 1            1                  Beale    0.762636
# 2            2                  Booth    0.010222
# 3            3           Bohachevsky1    0.000061
# 4            4           Bohachevsky2    0.013201
# 5            5               BoxBetts    0.000536
# 6            6                Branin1    0.398639
# 7            7                Branin2    0.000447
# 8            8                 Camel3    0.056140
# 9            9                 Camel6   -1.026518
# 10          10            Chichinadze  -41.835028
# 11          11                   Cola    0.007515
# 12          12               Colville  393.136655
# 13          13                 Corona    0.001546
# 14          14                  Easom   -0.000000
# 15          15              EggHolder -934.440417
# 16          16                   Exp2    1.009241
# 17          17                 Hansen -145.477737
# ...
